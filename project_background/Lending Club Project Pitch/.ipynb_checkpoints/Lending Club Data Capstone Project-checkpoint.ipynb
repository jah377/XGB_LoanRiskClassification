# %% [markdown]
# # FinTech/Lending Club Capstone Project Outline
# The Project is based on P2P lending site **Lending Club**'s dataset.
# There are many different versions available on kaggle.
# The one we use is of the longest duration, 2007-2018Q4. You can access the
# data through the following link https://www.kaggle.com/wordsforthewise/lending-club

# %%
from IPython.display import Image
Image(filename='lending club.png')

# %%
from IPython.display import Image
Image(filename='lending club.jpg')

# %% [markdown]
# ### Project Layout
#
# - step 1: Understanding the business model of Lending Club
#   - Please discuss with your team members the business models of P2P consumer lending, particularly **Lending Club**.  How does **Lending Club** compete with the traditional banks? What are the differences in their business models?
#     - As a lender, why do they get attracted to **Lending Club** instead of the alternatives in traditional banking industry?
#     - As a borrower, how are the loan terms of **Lending Club** attractive to them?
#   - You may refer to https://www.lendingclub.com/public/how-peer-lending-works.action for some overview and their wiki page https://en.wikipedia.org/wiki/LendingClub for more details.
#
# - step 2: Understanding the basics of key financial terms relevant to this
# project.
#     - **Lending Club** is in the fin-tech industry,
#     thus its data makes use of a lot financial terminologies. Thus it is vital to have some basic understanding on these terms.
#     - What is **FICO** score? How is it determined?  You may refer to
#       the sub-page  https://en.wikipedia.org/wiki/Credit_score_in_the_United_States#FICO_score for an overview.  The full article 'Credit score in the United States'
#       may also be useful.
#
#     - What are the differences of installment credit and revolving credit?
#     You may refer to https://www.investopedia.com/ask/answers/110614/what-are-differences-between-revolving-credit-and-installment-credit.asp for an answer.
#
#     - **Installment and Amortization**: For installment loans, what does 'installment' mean?  What is **amortization** schedule? You may consult
#     https://en.wikipedia.org/wiki/Amortizing_loan to understand the concept of **loan amortization**. In this article, it is explained clearly that the **amortization** shorten the average duration of the loan money (called **weighted average life** in the article).  For the computational aspect of **principal and interest** **amortization**, the formulae are in
#     https://en.wikipedia.org/wiki/Amortization_calculator
#
#     - **Prepayment Risk**: What does it mean? In **Lending Club's** loan practice, which party bears the **prepayment risk**? Is there any penalty for prepaying the debt?
#     - In the **Lending Club** dataset, a loan is labeled either 'Fully Paid', 'Current', 'Late', 'Grace period', 'Default', 'Charged Off', etc.
#     What do they mean?
#     - Do you know the difference between **loan default** and **loand delinquent**?  Check https://www.investopedia.com/ask/answers/062315/what-are-differences-between-delinquency-and-default.asp
#     - What does **loan settlement** mean?
#     - What does **loan collection** mean?
#
#
#     - What are the different types of risks in investing in **Lending Club** loans? You may find
#     relevant information by reading the following article on **Lending Club**.
#     https://www.financialsamurai.com/how-is-lending-club-doing-in-2018/
#
#     - The investor education center of **Lending Club** at https://www.lendingclub.com/investing/investor-education
#         can be useful for you.
#
# - It may benefit you to discuss among your team members the recent rise of **machine learning** in credit risk modeling/score.
# https://www.ciodive.com/news/equifax-debuts-machine-learning-based-credit-scoring-system/520095/
#   and
# https://www.moodysanalytics.com/risk-perspectives-magazine/managing-disruption/spotlight/machine-learning-challenges-lessons-and-opportunities-in-credit-risk-modeling

# %% [markdown]
# - step 3: Data Analysis
# - In general, your data analysis need to adhere to a firm business objective of your post.
#     - A few use cases:
#         - You are a data scientist at **Lending Club**.
#             - Summarize the historical loan data to educate the consumers.
#             - Educate the lenders the importance of loan diversification.
#             - Decide the interest rates of each loan-grade.
#             - Design a supurb loan-grade system using machine learning.
#             - Internal business monitoring.
#             - Spotting loans which will eventually go default with higher accuracy.
#                   ....
#         - You are a data scientist of a start-up investment firm, which plans to
#             invest in the loans of **Lending Club**.
#             - Conduct research and business report to investigate the potential to invest in **Lending Club** loans.
#             - Use machine learning to select/construct loan portfilios with superb return-risk profiles.
#             - Find ways to scale up the portfilios (called portfolio capacity) preserving performance.
#         - You are a data scientist of a competing fin-tech company.
#             - Reverse-Engieer the proprietery **Lending Club** loan-grade/sub-grade and try to do better. By the way, **Lending Club** makes use of social network information to assess the risk profiles
#                 of the borrowers. Your own loan-grade model probably could enhance their ranking instead of completely duplicating it.
#         - You are a personal investor who intends to buy loans from **LendingClub** or to buy from the secondary loan market.
#         - In all cases, you want to dig out important business insights relevant to
#     your business. Remember that your contribution would be **gauged by its impact to
#     your business**.
#        - Data analysis used in the pipeline of machine learning, which ties to the business need.

# %% [markdown]
# - To ease your burden, a plan skeleton is provided which asks you some relevant questions.
# - You are free to go beyond this, but this mandatory
# list could inspire you to dig deeper.
# - Some aspect of the data could be analyzed by 'survival/hazard' analysis. You can either
# start from scratch and learn from the mistakes you make in the process, or
# adopt some special-purpose data analysis/machine learning packages for survival analysis.
# - If you intend to bypass the trial-and-error approach of going from scratch,
# you will need to pick up special tools developed before and
# learn to read their documentations and papers. Both machine learning based and statistical modeling techniques
# are used in the literature for such study.

# %% [markdown]
# - No matter you are peformaing data analysis or machine learning, understanding the
# borrower (debtor) loan repayment behavior is vital to the success of loan business.

# %% [markdown]
# ### Warm Up Question
# The dataset contains $2.2M+$ of approved loans and $20M+$ rejected
# loan applications.
# - Among all the $151$ columns of the loan data set, which information **is known at the time
# of loan issuance**?
# - Which columns are related to borrowers's credit history and demographic information?
# - Which columns store loan-specific information?

# %% [markdown]
# ### Question
# - How does the issued loans vary year after year?
# - What are the purposes of applying **Lending Club** loans?
# - Do you observe different loan grade patterns for different loan purposes?
# - Do you observe different loan grade patterns in different years?
# - How about loan counts stratified into years and loan purposes/loan grades?

# %% [markdown]
# ### Question
# - How are the loan amounts/funded amounts distributed?
# - Are there variations across different loan purposes, loan grades, etc?
# - Are loans with higher funded amounts harder to be paid-in-full?

# %% [markdown]
# ### Question:
# - For borrowers, the most important factor is **interest rate** charged.
# - Provide insights on the **interest rates** dependence on loan grade/subgrade and term (36 or 60 months).
# - If the analysis is refined by separating loans with different start months
# (the year-month loan issuance date), report your finding.
# - Any rational explanation on why the **interest rate** should be grade/sub-grade
# dependent?
# - Any rational explanation on the time series variations of interest rates?
# - Any rational explanation why the interest rate rise w.r.t. loan term?

# %% [markdown]
# ### Question:
# - For investors, it is crucial to know whether a loan is served to completion (loan_status 'Fully Paid').
# - Please analyze the percentages of non-completed loans in each loan grade/subgrade
# (i.e. default, charged off) which go beyond **delinquency**.
# - Provide justification the introduction of loan grade/subgrade.
# - Provide justification on the rate hike on riskier loan grade/subgrade.
# - What happens to percentage rates of loans involving settlement?
# - Make sure that your analysis takes into account of **loan-term**.

# %% [markdown]
# ### Question:
# - For investors, the **amortization process** returns the partial principal and
# monthly interest in a single montly installment payment.
# - Because the borrower can pre-pay the principal at-will or go belly-up (delinquent or default) at any
# moment within the loan term, it may shorten the loan duration un-expectedly or
# cause losses to the investors.
# - Thus it is vital for the investors to know the general pattern of loan-prepayment
# or delinquency (early stage leading to default or eventual charged off).
# - Please compute the actual durations of loans (last_payment_date - issuance_date)
# and
#     - analyze the pattern debtors terminate the loans before loan maturity
#     (either 'fully paid', or stop paying henceforth).
#     - Please include 'term', 'loan-grade/sub-grade' in your analysis.
# - Do you see major differences on the patterns with different loan-terms?
# What is the rational explanation for this difference?
#
# - Report the major characteristics of the patterns.
# - Do '60 months' (5 years) loans often get terminated at the end of the 5 years
# loan term? Why not?

# %% [markdown]
# ### Question:
# - For investors, the profitability of the loans is of their central
# concern.
# - For a given loan, the profit-and-loss (in percentages) can be computed as
# the (total_payment - principal)/principal.
# - For those loans which are eventually 'Fully Paid', what are the average
# returns (or the distributions of returns) of different loan grades/terms?
# - For those loans wich are default or beyond, what are the average returns or return distributions?
# - What about all the loans which have been
# terminated ('fully paid', 'default', 'charged off')?
# - What about the loans which end up in **loan settlement negotiations**?
# - Any variation of patterns for different loan purposes?
# - What happens if the issuance years are included in your analysis?
# - Is there any pattern between loan duration vs return rate?

# %% [markdown]
# Question: Survival Analysis on Survival Probabilities
# - In the context of **Lending Club Loans**, a loan starts to default $121$ days
# after it fails to make the payment on time.
# - For loans which are eventually paid in full, analyze the probabilities
# of survival at different time durations (known as survival plot). How are these probabilities of 'survival'
#  related to the loan grade/subgrade or the FICO scores of the borrowers?
# To visualize, you want to plot the so-called **survival curve**.
# - For loans which are eventually defaulted, analyze the probabilities of
# survival at different time durations and find out its relationship with loan
# grade/subgrade, FICO scores or the other credit related attributes.
# - Lumping defaulted loans and completed loans together, a loan either pre-pays early
# , defaults or completes at maturity. Perform survival analysis and study what
# features affect the patterns.
#
# - You can either compute from the raw data from scratch, or use R-package like **survminer**
#  to assist your analysis.
# - In **survival analysis** jargon, the dual cause of the early termination of the loan (either early prepayment or default)
# is usually known as **competing events/competing risks**, or **mixture cure** model.

# %% [markdown]
# - Beyond these basics, you should explore and find your own data analytical insights.

# %% [markdown]
# ### Optional Quantitative Data Analysis Mini-project
# - As a data scientist at **Lending Club**, provide strong evidence to educate the
# lenders why diversification is important.
# - For simplicity, compare the investment returns of three types of loan portfolios
# - 20 equal-dollar investments in 20 grade A loans.
# - 100 equal-dollar investments in 100 grade A loans.
# - 20 equal-dollar investments in $5+5+5+5$ loans in grade $A, B, C, D$, respectively, $5$
# in each grade.
# - 100 equal-dollar investments in $25+25+25+25$ loans in grade $A, B, C, D$, respectively,
#  $25$ loans in each grade.
# - Or you can invest 1% (of the loan amount) and diversify into many loans.
#
# - Because there is uncertainty invovled, simulate by randomly drawing from grade A, B, C, D loan buckets.
# - Because loans often terminate prematurely, in order for the comparison to
# be objective, you will need to annualize the returns by first computing the average
# duration of your loan portfolios.
# - To be more accurate, you can take 'issuance date' into account and offer
# simulation during different years (or year-months).
# - Due to the stochastic nature of the problem at hand, you should analyze
# the mean annualized returns, risks of each type of portfolios, probability of loss, etc.
#
# - Alternatively, as a data scientist at a start-up investing firm, provide a business report
# whether loan-investing buying **Lending Club** loans is an attractive option,
# compared to short-term treasury/corporate funds?

# %% [markdown]
# ### Optional
# - The interest rates **Lending Club** loans charge to individual debtors depend on
# the **issuance dates** and macro-economical conditions at issuance.
# - Thus it might be mis-leading to compare two loans both
# with $10\%$ total profits, one in $2008$, another one in $2015$.
# - An alternative angle to analyze is to compute the expected returns and
# **weighted average life** assuming that the loans are paid-up at the end of the terms.
# - Once we use these as the benchmarks, we can gauge the return short-fall (as percentages)
# and duration short-fall (again as percentages) as more objective gauges to
# borrowers' behaviors.
# - Analyze the return short-falls and investment duration short-falls across
# different year-months.  Do you oberve any changes of borrower behaviors across the
# years?

# %% [markdown]
# #### Remark:
# - It can be shown easily that the weighted average life (as discussed in
# wiki) is the sum of time-varying principals/initial principal.
#
# - Based on the formula in **Amortization formula**, https://en.wikipedia.org/wiki/Amortization_calculator, we can code the
# **weighted average duration** and **total interest** in the most ideal situation (terimated at maturity, with no penalty, no settlment, ...) as

# %%
### N    - terms in months
### rate - monthly interest rate ~ annual interest rate/12

def Weighted_Average_Duration(N, rate):
    if np.isnan(N) or np.isnan(i): return np.nan
    
    p = 1.0-(np.exp(np.arange(N+1)*np.log(1+rate))-1)/(np.exp(N*np.log(1+rate))-1)
    # principals time series
    return np.sum(p)

def Total_Cumulative_Interest(N, rate):
    if np.isnan(N) or np.isnan(rate): return np.nan

    fac = np.exp(-N*np.log(1+rate))
    return N*rate/(1-fac)-1

# %% [markdown]
# ### Optional Open Data Analytic Question
# - What types of loans tend to prepay and terminate within 3 months of the
# loan issuance?
# - What types of loans tend to default (or go into charged off) within a short duration after issuance?
# - A good investor may want to avoid these types of loans.
# - The insights might be used in ML task to single out these bad loans.

# %% [markdown]
# ### Optional Data Analysis Question
# - Does default rate (including those get **charged off** or into **settlement**) holds
# constant across different time (year-months)?
# - If not, what are the external driving forces which cause the default rate to rise or fall?
# - Can you provide data and statistical evidence for your analysis?

# %% [markdown]
# ### Machine Learning Project Ideas
# - We propose several ML ideas of different levels of difficulty.
# - Some questions may become long-term projects. If so, you are responsible
# to transform business objectives into ML objectives and formulate the
# questions into several feasible stages.
# - We realize that the timeline of our capstone project is short, so we
# value ingenious ideas/sound and rational approach over high model accuracy.
# - It is not that model accuracy is not important, it is that with a short
# duration like this, it makes more sense to make partial progress on some
# idea which is convincing, than failing to fit a highly accurate model.
# - At the end the success of the project is gauged by the employers. The ultimate objectives is to **convince the hiring employers that you have a solid learning
# in the relevant industry practices**, where model accuracy is only one among
# many on the check-list.
# - Credit risk modeling, default rate modeling, default predictions, time-until-default are
# all important subjects in banking finance, where a large amount of
# resources and time
# in the finanical industry and the academic circle had been allocated to tackle the problem.
# - You will need to balance your time in picking up necessary domain knowledge or
# try and err.
# - Besides considering my suggestions, you can also frame your own questions or
# follow the route of **survival/hazard analysis** to frame your questions.
#
# - In case you use more than one scorer (**MSE** or **AUC**) in your **gridsearchCV**, notice that **sklearn** allows you
# to compute multiple scorers (even using customed scorers you define) in a single
# round of **gridsearchCV**.

# %%
#### Caution:
- In training your **predictive** ML model, you can only use whichever feature columns which are known at the time of issuance.
- For example, it doesn't make sense to use the **loan_status** column to
predict whether the loan will eventually go through 'settlement negotiations'.
At the time of loan issuance, the investor has no way to know for sure whether the loan will default or fully paid.

# %% [markdown]
# ### Pooled Models vs Time Series Models
# - The column 'issue_d' (**issuance date**) is in the year-month format.
# - When we treat it as a categorical column representing differnt sub-groups of data points, the **pooled model**, a jargon of statisticians, refers to
# the model trained by lumping all data of different issuance dates together.
# - In comparison, a time series ML model trains sequentially the data points with different issuance dates and the model evolve w.r.t. time as new data points come in.
# - The pooled model summarizes the historical data, which can be used as a
# baseline of future time-series ML models.
# - On the other hand, the sequential (batch) models micmic the real-world
# scenario as the real-world data comes in month-after-month.

# %% [markdown]
# ### Classification Tasks

# %% [markdown]
# ### Project Idea 1:
# - Make a simplifying assumption between the **loan issuance date** and application dates,
# convert the approved loans into the formats of rejected loan applications.
# - Use supervised technique and clustering, describe (reverse engineering)
# the loan approval criterion of **Lending Club**.
#
#     - Challenges: The aggregated data has more than $20M$ samples. This is
#         beyond the coverage of many ML algorithms. How do you design an apporach
#         which allows you to train on such a large size data? The problem is
#         particularly serious for training **pooled** models.
#     - When you apply supervised technique, it might involve imbalanced classification.
#     How would you handle 'im-balanced dataset' like this?
#
# - Are there poor performing approved loans which should be rejected?
# - What is the business impact (pros and cons) of rejecting such non-performing loans?

# %% [markdown]
# ### Project Idea 2:
# - A good loan (from the prospective of an investor) pays
# the interests and fractional principals on time and terminate at loan maturity.
# - An investor often lose money when a loan goes into default, settlement,
# or 'written off' (called **charged off** in this data set).
# - Build a supervised model to make **multi-label** prediction on 3 dimensions
# "charged off + default", "settlement involved", "hardship".
# - This can be used either by **Lending Club** itself or a third-party investing firm
# for loan-grade design or accurated portfolio selection.
# - Depending on the scope of your project, you may
#     - tackle a single label prediction.
#     - restrict to the pooled models.
#     - focus on the time seris models
# - This is a **multi-label** binary imbalance classification task.
# - If you train a **pooled** model, you have to deal with $2M+$ samples, often too
# large for a typical ML algorithm to handle.
#
# - Try several imbalance classification techniques and evaluate their performance.
#
# - Based on your business, discuss the negative impacts of type I (false
# positive), type II (false negative) errors in your prediction.
#
# - If you decide to train a time series model, make sure that you have some
# basic background on performing hyper-parameter tuning in the time series context.
#
# - **MUST**: A defaulted loan with a loan amount $\$1000$ has a totally different
# impact to the final profit than a defaulted $\$50000$ loan.
#    - Discuss whether the **classroom-taught** machine learning techniques
#     addresses these issues. How would you modify the classifier to take into account
#          - your business objectives.
#          - the profit and loss focus.
#
# - Can you use **NLP** technique to extract insights on the loan descriptions
# which helps your predictive task?

# %% [markdown]
# ### Project Ideas 3
# - A loan investor often performs screening on the finanical instruments
# into a subset he/she intends to invest.
# - Depending on the desired capacity of investing,
# the loan investor may want to exclude any bad loan which is expected to
# lose, say $30\%$ of its principal or more, or keeping loans whose expected performance (in annualized returns)
# are above grade dependent thresholds.
# - Train a classifier for such a task.
# - Please take into account the loan sizes in your ML task.
# - How does type I or type II errors impact your investing?  Should your
# model treat type I and type II errors equally?
# - While high accuracy is always welcome, what is the most adequate objective for your investment screening?

# %% [markdown]
# ### Regression Tasks

# %% [markdown]
# ### Project Idea 4:
# - Whether the potential profit of the loan can compensate the risks taken by the
# investor depend on the interest rate (relative to the loan term) and the
# loan pre-payment expectation.
# - On the other hand, the interest rate that **Lending Club** decides depends on
# multiple loan-specific, company (**Lending Club**) specific and macro-economical
# conditions (fed rates, unemployment rate, bond market yield curves), etc.
# - The goal of the project is to build an interest rate model based on the
# loan interest rate data.
# - Decide the business objectives of the interest rate modelling.
# - The goal is to unveil the interest-rate decision rules.
# - You may need to introduce macro-economical or exgogeneous financial data
# to enhance your model performance.
# - Either a **pooled** approach or **time-series** approach is possible.
# - Do you plan to build individual models of differnt loan-term/loan-grade
# or estimate a grand-model treating loan-term/loan-grade as data attributes?
# - Discuss and evaluate the pros and cons of different approaches.

# %% [markdown]
# ### Project Idea 5: Survival Time Analysis
# - A loan which gets repaid within a few months has no value to the investor.
# - It is negative to the investors beacause of the **opportunity cost** of investing.
# - A loan which defaults quickly after issuance is even worse. It often induces
# a larger loss.
# - Thus it is very important for the loan investor to have an accurate expectation on
# the loan-performance (in terms of duration or net PnL).
# It is even more important when the loan is sold by the original investor to
# the secondary market, a correct expectation on the remaining term of the loan and
# the default rate is crucial for a correct pricing of the loan.
# https://www.lendingclub.com/investing/investor-education/are-lendingclub-notes-liquid
# - Build models to predict loan duration (last_payment_date - issuance_date)
# for charged off/default loans and for good loans which terminate with 'fully paid' status.
# - Build models to predict total profits/losses (or total principal/interest)
#
# - Show evidences to link the loan-duration and the PnL, which may justify
# training a joint model predicting multi-regression-targets.
#
# - Modeling the survival of loans is a very important topic across different domains.
# In health care/health insurance it is usually called survival analysis.
# In modeling product life expectancy, engineers use a different term reliability analysis.
# The same type of thought can be used on financial instrument default or marketing/customer retention.
# - Note that there is an add-on survival analysis package 'scikit-survival' on top of **sklearn**.
# There are a ton of packages in R dedicated to survival analysis, visit
# https://cran.r-project.org/web/views/Survival.html for a survey.
# - You can either start from scratch or adapt the traditional approach of
# survival/hazard analysis. In the latter approach, you need to read research papers effectively.

# %% [markdown]
# ### Project Idea 6:  Annualized Loan Return Prediction
# - From the prospective of the investors, the profitability of the loans is
# crucial for their success.
# - Please build a model predicting the loan annualized returns based on the
# features known at the time of loan initialization.
# - Because the final outcome is the total profit of the loan, please formulate your regression
# problem so that it takes care the sizes of the loans.
# - Please evaluate whether it is a better idea to build individual models for different loan grades/sub-grades or pooling them together.
# - A predictive task can only use information available at the time of issuance. Thus the column 'loan_status',... cannot be used.
# - If you intend to feature-engineer columns not known at the time of loan initialization, you have to
# build a classifier to predict them and use the predicted values as your new feature.
#
# For example, whether the loan will be default or not is not known at the
# time of loan initialization. While it is o.k. to use the predicted default
# flag as your feature, it is not o.k. to use the true default flag as your predictive feature.
